# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import (
#     accuracy_score, 
#     precision_score, 
#     recall_score, 
#     f1_score, 
#     confusion_matrix, 
#     classification_report
# )
import pandas as pd

# Load dataset
df = pd.read_csv("Financial Sentiment Analysis.csv")
df = df[['Sentence', 'Sentiment']].dropna()

# Make sure the labels are consistent
df['Sentiment'] = df['Sentiment'].str.lower()

# Preview
print(df['Sentiment'].value_counts())
df.head()
# Out:
# Sentiment
# neutral     3130
# positive    1852
# negative     860
# Name: count, dtype: int64
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
# # 1. Load the data (update the path if needed)
# df = pd.read_csv('Financial Sentiment Analysis.csv')
from skollama.models.ollama.classification.zero_shot import ZeroShotOllamaClassifier

# Init classifier (make sure ollama is running: `ollama run llama2`)
zero_shot_clf = ZeroShotOllamaClassifier(
    model="llama2",  # Use your preferred local model: llama2, mistral, gemma
    candidate_labels=["positive", "neutral", "negative"],
    hypothesis_template="This example is {} in sentiment.",
)

# %%
# # 2. Check and plot the distribution of labels in the *full* dataset
# label_counts = df['Sentiment'].value_counts()

# plt.bar(label_counts.index, label_counts.values)
# plt.title("Overall Label Distribution (Full Dataset)")
# plt.xlabel("Sentiment")
# plt.ylabel("Count")
# plt.show()

# Take a sample of 50 for now (to keep it fast)
sample_df = df.sample(50, random_state=42).copy()

# 3. Initialize Zero-Shot Classifier
zero_shot_clf = ZeroShotOllamaClassifier(
    model="llama2",  # Or use 'mistral', 'gemma', etc.
    candidate_labels=["positive", "neutral", "negative"],
    hypothesis_template="This sentence is {} in sentiment."
)

# ⚠️ 4. Call .fit() with dummy data to initialize internal structures
zero_shot_clf.fit(["dummy sentence"], ["neutral"])

# Run prediction
sample_df['ZeroShot_Predicted'] = zero_shot_clf.predict(sample_df['Sentence'].tolist())


# 6. Preview results
print(sample_df[['Sentence', 'Sentiment', 'ZeroShot_Predicted']].head())

# 7. Evaluate performance
from sklearn.metrics import classification_report
print("\nClassification Report (Zero-Shot):")
print(classification_report(sample_df['Sentiment'], sample_df['ZeroShot_Predicted']))
# sample_df[['Sentence', 'Sentiment', 'ZeroShot_Predicted']].head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [12:35<00:00, 15.11s/it]
#                                                Sentence Sentiment  \
# 4584  A few employees would remain at the Oulu plant...   neutral
# 177   Comparable net sales are expected to increase ...  positive
# 167   Tesla is recalling 2,700 Model X cars: https:/...  negative
# 5585  Finnish software developer Done Solutions Oyj ...  positive
# 2339  Compagnie de Financement Foncier - Is to issue...   neutral
#
#      ZeroShot_Predicted
# 4584            neutral
# 177             neutral
# 167             neutral
# 5585            neutral
# 2339            neutral
#
# Classification Report (Zero-Shot):
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         8
#      neutral       0.50      1.00      0.67        25
#     positive       0.00      0.00      0.00        17
#
# ...

# %%
# # 3. Split the dataset into training & testing
# #    - test_size=0.2 => 20% for test, 80% for train
# #    - random_state=42 => ensures reproducibility
# train_df, test_df = train_test_split(
#     df, 
#     test_size=0.2, 
#     random_state=42, 
#     stratify=df['Sentiment']
# )
from skollama.models.ollama.classification.few_shot import FewShotOllamaClassifier

# Provide 1–3 examples per class
examples = [
    ("The company reported record-breaking profits this quarter.", "positive"),
    ("The board held its regular meeting with no major announcements.", "neutral"),
    ("The company is facing a class action lawsuit after fraud allegations.", "negative"),
]

few_shot_clf = FewShotOllamaClassifier(
    model="llama2",
    candidate_labels=["positive", "neutral", "negative"],
    examples=examples
)

# %%
# # # 4. Convert text data to TF-IDF features
# # vectorizer = TfidfVectorizer()
# # X_train = vectorizer.fit_transform(train_df['Sentence'])
# # X_test = vectorizer.transform(test_df['Sentence'])

# # y_train = train_df['Sentiment']
# # y_test = test_df['Sentiment']

# sample_df['FewShot_Predicted'] = few_shot_clf.predict(sample_df['Sentence'].tolist())
# sample_df[['Sentence', 'Sentiment', 'FewShot_Predicted']].head()

## from sklearn.metrics import classification_report

## print("Zero-Shot Evaluation:\n")
## print(classification_report(sample_df['Sentiment'], sample_df['ZeroShot_Predicted']))

## print("Few-Shot Evaluation:\n")
## print(classification_report(sample_df['Sentiment'], sample_df['FewShot_Predicted']))



from skollama.models.ollama.classification.few_shot import FewShotOllamaClassifier

# Few examples to guide the model
examples = [
    ("The company posted record profits this quarter.", "positive"),
    ("The market reacted negatively to the new tax policy.", "negative"),
    ("The board held a routine quarterly meeting.", "neutral"),
]

# Initialize Few-Shot classifier
few_shot_clf = FewShotOllamaClassifier(
    model="llama2",  # Use the same model you pulled
    candidate_labels=["positive", "neutral", "negative"],
    examples=examples
)

# Fit with dummy data (required)
few_shot_clf.fit(["dummy sentence"], ["neutral"])

# Predict
sample_df['FewShot_Predicted'] = few_shot_clf.predict(sample_df['Sentence'].tolist())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [15:44<00:00, 18.88s/it]

# %%
from sklearn.metrics import classification_report

# Optional: Silence sklearn warning about 0 precision
import warnings
warnings.filterwarnings("ignore")

print("Zero-Shot Evaluation:\n")
print(classification_report(sample_df['Sentiment'], sample_df['ZeroShot_Predicted']))

print("\nFew-Shot Evaluation:\n")
print(classification_report(sample_df['Sentiment'], sample_df['FewShot_Predicted']))
# Out:
# Zero-Shot Evaluation:
#
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         8
#      neutral       0.50      1.00      0.67        25
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.50        50
#    macro avg       0.17      0.33      0.22        50
# weighted avg       0.25      0.50      0.33        50
#
#
# Few-Shot Evaluation:
#
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         8
#      neutral       0.50      1.00      0.67        25
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.50        50
#    macro avg       0.17      0.33      0.22        50
# weighted avg       0.25      0.50      0.33        50

# %%
sample_df[['Sentence', 'Sentiment', 'ZeroShot_Predicted', 'FewShot_Predicted']].head(10)
# Out:
#                                                Sentence Sentiment  \
# 4584  A few employees would remain at the Oulu plant...   neutral
# 177   Comparable net sales are expected to increase ...  positive
# 167   Tesla is recalling 2,700 Model X cars: https:/...  negative
# 5585  Finnish software developer Done Solutions Oyj ...  positive
# 2339  Compagnie de Financement Foncier - Is to issue...   neutral
# 1047  The works will include the laying of natural s...   neutral
# 4678  Peer Peugeot fell 0.81 pct as its sales rose o...  negative
# 3957  A memorandum of understanding on cooperation b...  positive
# 2534  The Vaisala Group is a successful internationa...  positive
# 1501  New Credit Suisse boss faces stiff challenge i...  negative
#
#      ZeroShot_Predicted FewShot_Predicted
# 4584            neutral           neutral
# 177             neutral           neutral
# 167             neutral           neutral
# 5585            neutral           neutral
# ...

# %%
# # 5. Train a Logistic Regression model
# clf = LogisticRegression(random_state=42, max_iter=500)
# clf.fit(X_train, y_train)

import matplotlib.pyplot as plt

# Distribution of predictions
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

sample_df['ZeroShot_Predicted'].value_counts().plot(kind='bar', ax=axs[0], title='Zero-Shot Prediction Distribution')
sample_df['FewShot_Predicted'].value_counts().plot(kind='bar', ax=axs[1], title='Few-Shot Prediction Distribution')

plt.tight_layout()
plt.show()

# %%
# # 6. Predict sentiment on the test set
# y_pred = clf.predict(X_test)

def batch_predict(model, sentences, batch_size=20):
    predictions = []
    for i in range(0, len(sentences), batch_size):
        batch = sentences[i:i+batch_size]
        preds = model.predict(batch)
        predictions.extend(preds)
    return predictions

# Example usage
df['ZeroShot_Full'] = batch_predict(zero_shot_clf, df['Sentence'].tolist(), batch_size=25)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [04:12<00:00, 14.88s/it]

# %%
# 7. Evaluate Performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Classification Report:")
print(classification_report(y_test, y_pred))

print(f"Accuracy:  {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall:    {recall:.3f}")
print(f"F1 Score:  {f1:.3f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.31      0.13      0.18       172
#      neutral       0.71      0.88      0.79       626
#     positive       0.76      0.66      0.71       371
#
#     accuracy                           0.70      1169
#    macro avg       0.59      0.56      0.56      1169
# weighted avg       0.67      0.70      0.67      1169
#
# Accuracy:  0.700
# Precision: 0.667
# Recall:    0.700
# F1 Score:  0.672

# %%
# 8. Plot confusion matrix as a heatmap-like figure using Matplotlib
cm = confusion_matrix(y_test, y_pred, labels=['negative','neutral','positive'])

fig, ax = plt.subplots(figsize=(5,4))
cax = ax.imshow(cm, cmap='viridis')
ax.set_title('Confusion Matrix')
ax.set_xticks([0,1,2])
ax.set_yticks([0,1,2])
ax.set_xticklabels(['negative','neutral','positive'])
ax.set_yticklabels(['negative','neutral','positive'])

# Show raw values inside the heatmap
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i,j], 
                ha="center", va="center", 
                color="white", fontsize=12)

fig.colorbar(cax)
plt.show()

# %%
# 9. Plot distribution of labels: test set vs. predicted
test_label_counts = test_df['Sentiment'].value_counts()
pred_label_counts = pd.Series(y_pred).value_counts()

# a) Bar plot for test set distribution
plt.bar(test_label_counts.index, test_label_counts.values)
plt.title("Test Set Label Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# b) Bar plot for predicted distribution
plt.bar(pred_label_counts.index, pred_label_counts.values)
plt.title("Predicted Label Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
